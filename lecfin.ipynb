# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('shampoo.csv', header=0, parse_dates=[0])

# %%
df['Sales'].plot()
# Out:
# <AxesSubplot:>

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df['Sales'])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(df['Sales'], lags=15)
# Out:
# D:\anaconda\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model = ARIMA(df['Sales'], order=(5,2,2))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14088\659453970.py in <module>
# ----> 1 model = ARIMA(df['Sales'], order=(5,2,2))
#
# D:\anaconda\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# D:\anaconda\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %%
model = ARIMA(df['Sales'], order=(5,2,2))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14088\659453970.py in <module>
# ----> 1 model = ARIMA(df['Sales'], order=(5,2,2))
#
# D:\anaconda\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# D:\anaconda\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %%
model_fit.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14088\4184862335.py in <module>
# ----> 1 model_fit.summary()
#
# NameError: name 'model_fit' is not defined

# %%
df = pd.read_csv('shampoo.csv', header=0, parse_dates=[0])

# %%
df.head()
# Out:
#     Month  Sales
# 0  01-Jan  266.0
# 1  01-Feb  145.9
# 2  01-Mar  183.1
# 3  01-Apr  119.3
# 4  01-May  180.3

# %%
train_size=int(df.shape[0]*0.7)

# %%
train,test=df.Sales[0:train_size],df.Sales[train_size:]

# %%
test.shape
# Out:
# (11,)

# %%
data = train
predict =[]
for t in test:
    model = ARIMA(data, order=(5,1,0))
    model_fit = model.fit()
    y = model_fit.forecast()
    print(y[0][0])
    predict.append(y[0][0])
    data = np.append(data, t)
    data = pd.Series(data)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14088\2062792948.py in <module>
#       2 predict =[]
#       3 for t in test:
# ----> 4     model = ARIMA(data, order=(5,1,0))
#       5     model_fit = model.fit()
#       6     y = model_fit.forecast()
#
# D:\anaconda\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# D:\anaconda\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv('us-airlines-monthly-aircraft-miles-flown.csv', header=0 , parse_dates=[0])

# %%
df.index = df['Month']

# %%
result_a=seasonal_decompose(df['MilesMM'],model='multiplicative')
result_a.plot()

# %%
model = SARIMAX(df['MilesMM'], order=(5,1,3), seasonal_order=(1,1,1,12))
# Out:
# D:\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# D:\anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_fit = model.fit()
# Out:
# D:\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\anaconda\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
residuals = model_fit.resid

# %%
residuals.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
output = model_fit.forecast()

# %%
output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14088\2415424161.py in <module>
# ----> 1 output
#
# NameError: name 'output' is not defined

# %%
model_fit.forecast(12)
# Out:
# 1971-01-01    11476.000788
# 1971-02-01    11153.739113
# 1971-03-01    13670.158786
# 1971-04-01    12648.006632
# 1971-05-01    14338.913895
# 1971-06-01    15786.366118
# 1971-07-01    14979.451132
# 1971-08-01    15362.649708
# 1971-09-01    16963.089291
# 1971-10-01    13681.987053
# 1971-11-01    12426.872790
# 1971-12-01    13730.460296
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
yhat=model_fit.predict()

# %%
yhat.head()
# Out:
# 1963-01-01       0.000000
# 1963-02-01    5871.800077
# 1963-03-01    5421.975095
# 1963-04-01    7122.209703
# 1963-05-01    7067.882532
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
pyplot.plot(df['MilesMM'])
pyplot.plot(yhat, color='red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14088\1855587620.py in <module>
# ----> 1 pyplot.plot(df['MilesMM'])
#       2 pyplot.plot(yhat, color='red')
#
# NameError: name 'pyplot' is not defined
